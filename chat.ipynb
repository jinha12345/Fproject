# %%
from pymongo import MongoClient
from datetime import datetime

id = 'jinha12345'

# MongoDB 클라이언트 생성
uri = "mongodb+srv://jinha12345:mU3PiT5P1VrRvOYH@jinha.8og9mva.mongodb.net/?retryWrites=true&w=majority&appName=jinha"
client = MongoClient(uri)

def addtoMongoDB(message):
    global uri, client, id

    # 데이터베이스 선택
    db = client.Fproject

    # 컬렉션 선택
    collection = db.chat

    # 새로운 문서 추가
    new_message = {"id": id, "message": message, "created_at": datetime.utcnow()}
    result = collection.insert_one(new_message)
    
    # 추가된 문서의 ID 반환
    return result.inserted_id

# %%
client.Fproject.chat.create_index([("created_at", -1)])
# Out:
# 'created_at_-1'

# %%
for i in range(1, 101) :
    addtoMongoDB(str(i))

# %%
# 최신 10개 메시지 가져오기
latest_messages = client.Fproject.chat.find().sort("created_at", -1).limit(10)

# 메시지 출력
for message in latest_messages:
    print(message)
# Out:
# {'_id': ObjectId('67937025e50373aab8e9dc80'), 'id': 'jinha12345', 'message': '100', 'created_at': datetime.datetime(2025, 1, 24, 10, 49, 9, 781000)}
# {'_id': ObjectId('67937025e50373aab8e9dc7f'), 'id': 'jinha12345', 'message': '99', 'created_at': datetime.datetime(2025, 1, 24, 10, 49, 9, 771000)}
# {'_id': ObjectId('67937025e50373aab8e9dc7e'), 'id': 'jinha12345', 'message': '98', 'created_at': datetime.datetime(2025, 1, 24, 10, 49, 9, 759000)}
# {'_id': ObjectId('67937025e50373aab8e9dc7d'), 'id': 'jinha12345', 'message': '97', 'created_at': datetime.datetime(2025, 1, 24, 10, 49, 9, 748000)}
# {'_id': ObjectId('67937025e50373aab8e9dc7c'), 'id': 'jinha12345', 'message': '96', 'created_at': datetime.datetime(2025, 1, 24, 10, 49, 9, 737000)}
# {'_id': ObjectId('67937025e50373aab8e9dc7b'), 'id': 'jinha12345', 'message': '95', 'created_at': datetime.datetime(2025, 1, 24, 10, 49, 9, 726000)}
# ...

# %%
from pymongo import MongoClient
from datetime import datetime

id = 'jinha12345'

# MongoDB 클라이언트 생성
uri = "mongodb+srv://jinha12345:mU3PiT5P1VrRvOYH@jinha.8og9mva.mongodb.net/?retryWrites=true&w=majority&appName=jinha"
client = MongoClient(uri)

def addtoMongoDB(message):
    global uri, client, id

    # 데이터베이스 선택
    db = client.Fproject

    # 컬렉션 선택
    collection = db.chat

    # 새로운 문서 추가
    new_message = {"id": id, "message": message, "created_at": datetime.utcnow()}
    result = collection.insert_one(new_message)
    
    # 추가된 문서의 ID 반환
    return result.inserted_id

def getLatestMessage(n):
    messages = client.Fproject.chat.find().sort("created_at", -1).limit(n)
    messages = list(messages)[::-1]
    return messages

latest_messages = getLatestMessage(10)

for message in latest_messages:
    print(message)
# Out:
# {'_id': ObjectId('67937025e50373aab8e9dc77'), 'id': 'jinha12345', 'message': '91', 'created_at': datetime.datetime(2025, 1, 24, 10, 49, 9, 681000)}
# {'_id': ObjectId('67937025e50373aab8e9dc78'), 'id': 'jinha12345', 'message': '92', 'created_at': datetime.datetime(2025, 1, 24, 10, 49, 9, 692000)}
# {'_id': ObjectId('67937025e50373aab8e9dc79'), 'id': 'jinha12345', 'message': '93', 'created_at': datetime.datetime(2025, 1, 24, 10, 49, 9, 703000)}
# {'_id': ObjectId('67937025e50373aab8e9dc7a'), 'id': 'jinha12345', 'message': '94', 'created_at': datetime.datetime(2025, 1, 24, 10, 49, 9, 714000)}
# {'_id': ObjectId('67937025e50373aab8e9dc7b'), 'id': 'jinha12345', 'message': '95', 'created_at': datetime.datetime(2025, 1, 24, 10, 49, 9, 726000)}
# {'_id': ObjectId('67937025e50373aab8e9dc7c'), 'id': 'jinha12345', 'message': '96', 'created_at': datetime.datetime(2025, 1, 24, 10, 49, 9, 737000)}
# ...

# %%
latest_messages[0]['id']
# Out:
# 'jinha12345'

# %%
Messages = getLatestMessage(50)

a = '''
<div class="flex items-start gap-2.5">
<img class="w-8 h-8 rounded-full" src="/docs/images/people/profile-picture-3.jpg" alt="Jese image">
<div class="flex flex-col gap-1 w-full max-w-[320px]">
<div class="flex items-center space-x-2 rtl:space-x-reverse">
<span class="text-sm font-semibold text-gray-900 dark:text-white">
''' + Messages[0]['id'] + '''
</span>
<span class="text-sm font-normal text-gray-500 dark:text-gray-400">
''' + Messages[0]['created_at'].strftime("%m월 %d일 %H:%M").lstrip("0").replace(" 0", " ") + '''
</span>
</div>
<div
class="flex flex-col leading-1.5 p-4 border-gray-200 bg-gray-100 rounded-e-xl rounded-es-xl dark:bg-gray-700">
<p class="text-sm font-normal text-gray-900 dark:text-white">
''' + Messages[0]['message'] + '''
</p>
</div>
<span class="text-sm font-normal text-gray-500 dark:text-gray-400">　</span>
</div>
</div>'''


for i in range(0, 50):
    messages_HTML = messages_HTML + '''
<div class="flex items-start gap-2.5">
<img class="w-8 h-8 rounded-full" src="/docs/images/people/profile-picture-3.jpg" alt="Jese image">
<div class="flex flex-col gap-1 w-full max-w-[320px]">
<div class="flex items-center space-x-2 rtl:space-x-reverse">
<span class="text-sm font-semibold text-gray-900 dark:text-white">
''' + Messages[i]['id'] + '''
</span>
<span class="text-sm font-normal text-gray-500 dark:text-gray-400">
''' + Messages[i]['created_at'].strftime("%m월 %d일 %H:%M").lstrip("0").replace(" 0", " ") + '''
</span>
</div>
<div
class="flex flex-col leading-1.5 p-4 border-gray-200 bg-gray-100 rounded-e-xl rounded-es-xl dark:bg-gray-700">
<p class="text-sm font-normal text-gray-900 dark:text-white">
''' + Messages[i]['message'] + '''
</p>
</div>
<span class="text-sm font-normal text-gray-500 dark:text-gray-400">　</span>
</div>
</div>'''

print(messages_HTML)
# Out:
# <div class="flex items-start gap-2.5">
# <img class="w-8 h-8 rounded-full" src="/docs/images/people/profile-picture-3.jpg" alt="Jese image">
# <div class="flex flex-col gap-1 w-full max-w-[320px]">
# <div class="flex items-center space-x-2 rtl:space-x-reverse">
# <span class="text-sm font-semibold text-gray-900 dark:text-white">
# jinha12345
# </span>
# <span class="text-sm font-normal text-gray-500 dark:text-gray-400">
# 1월 24일 10:49
# </span>
# </div>
# <div
# class="flex flex-col leading-1.5 p-4 border-gray-200 bg-gray-100 rounded-e-xl rounded-es-xl dark:bg-gray-700">
# <p class="text-sm font-normal text-gray-900 dark:text-white">
# 51
# </p>
# </div>
# <span class="text-sm font-normal text-gray-500 dark:text-gray-400">　</span>
# </div>
# </div>
# <div class="flex items-start gap-2.5">
# <img class="w-8 h-8 rounded-full" src="/docs/images/people/profile-picture-3.jpg" alt="Jese image">
# <div class="flex flex-col gap-1 w-full max-w-[320px]">
# ...

# %%
Messages[0]['created_at']
# Out:
# datetime.datetime(2025, 1, 24, 10, 49, 9, 242000)

# %%
# !pip install pytz
# Out:
# ...
#    ---------------------------------------- 0.0/508.0 kB ? eta -:--:--
#     --------------------------------------- 10.2/508.0 kB ? eta -:--:--
#    ---------------- ----------------------- 204.8/508.0 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 508.0/508.0 kB 5.3 MB/s eta 0:00:00
# ...
